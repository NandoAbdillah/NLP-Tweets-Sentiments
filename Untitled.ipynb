# %%
# Membuat Label Sentiments

import pandas as pd
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

df = pd.read_csv(r'./tweets_clean.csv')

# %%
df.head()
# Out:
#                                           clean_text
# 0  ['smell', 'scent', 'hand', 'sanitizers', 'toda...
# 1  ['hey', 'yankees', 'yankeespr', 'mlb', 'make',...
# 2  ['diane', 'wdunlap', 'realdonaldtrump', 'trump...
# 3  ['brookbanktv', 'one', 'gift', 'covid', 'give'...
# 4  ['july', 'media', 'bulletin', 'novel', 'corona...

# %%
df['clean_text'] = df['clean_text'].apply(lambda s: ' '.join(eval(s)))

# %%
df.head()
# Out:
#                                           clean_text
# 0  smell scent hand sanitizers today someone past...
# 1  hey yankees yankeespr mlb make sense players p...
# 2  diane wdunlap realdonaldtrump trump never clai...
# 3  brookbanktv one gift covid give appreciation s...
# 4  july media bulletin novel coronavirusupdates c...

# %%
nltk.download('vader_lexicon')

sia = SentimentIntensityAnalyzer()

sentiments = []
for text in df.clean_text :
    sentiment = sia.polarity_scores(text)
    if sentiment['compound'] > 0:
        sentiments.append('positive')
    elif sentiment['compound'] < 0:
        sentiments.append('negative')
    else:
        sentiments.append('neutral')

df['sentiments'] = sentiments
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\nando\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
df.head()
# Out:
#                                           clean_text sentiments
# 0  smell scent hand sanitizers today someone past...   positive
# 1  hey yankees yankeespr mlb make sense players p...   positive
# 2  diane wdunlap realdonaldtrump trump never clai...   positive
# 3  brookbanktv one gift covid give appreciation s...   positive
# 4  july media bulletin novel coronavirusupdates c...   positive

# %%
df['clean_text'].loc[df['sentiments']=='negative'].head(60)
# Out:
# 5      coronavirus covid deaths continue rise almost ...
# 18        darkest moments must focus see light aristotle
# 22     jimbnntt image list source careful overall ris...
# 27     imagine people profit human suffer covid study...
# 30     fema acknowledge puertorico lack rebuild home ...
# 32     update total covid case recoveries deaths repo...
# 36     nicolekowalski chrisdameanor feel little anxio...
# 40     playyourpart fight covid one us make differenc...
# 43     delhi report covid positive case deaths saturd...
# 47     coronavirus test fiasco st mirren pledge under...
# 48     coronavirus test fiasco st mirren pledge under...
# 50     coronavirus test fiasco st mirren pledge under...
# 51     coronavirus test fiasco st mirren pledge under...
# 52     coronavirus test fiasco st mirren pledge under...
# 54     coronavirus test fiasco st mirren pledge under...
# 55     coronavirus test fiasco st mirren pledge under...
# ...

# %%
import matplotlib.pyplot as plt

# misalkan ini adalah data sentimen Anda
sentiments = df['sentiments']

# hitung jumlah setiap sentimen
sentiment_counts = sentiments.value_counts()

# buat diagram batang
plt.figure(figsize=(10,5))
plt.bar(sentiment_counts.index, sentiment_counts.values)
plt.show()

# atau buat diagram pie
plt.figure(figsize=(10,5))
plt.pie(sentiment_counts.values, labels=sentiment_counts.index, autopct='%1.1f%%')
plt.show()

# %%
df_ori = pd.read_csv('./covid19_tweets.csv')
df_ori.head()
# Out:
#          user_name         user_location  \
# 0           ᏉᎥ☻լꂅϮ            astroworld
# 1    Tom Basile 🇺🇸          New York, NY
# 2  Time4fisticuffs      Pewee Valley, KY
# 3      ethel mertz  Stuck in the Middle
# 4         DIPR-J&K     Jammu and Kashmir
#
#                                     user_description         user_created  \
# 0  wednesday addams as a disney princess keepin i...  2017-05-26 05:46:42
# 1  Husband, Father, Columnist & Commentator. Auth...  2009-04-16 20:06:23
# 2  #Christian #Catholic #Conservative #Reagan #Re...  2009-02-28 18:57:41
# 3  #Browns #Indians #ClevelandProud #[]_[] #Cavs ...  2019-03-07 01:45:06
# 4  🖊️Official Twitter handle of Department of Inf...  2017-02-12 06:45:15
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0             624           950            18775          False
# 1            2253          1677               24           True
# 2            9275          9525             7254          False
# ...

# %%
df_ori['sentiments'] = df['sentiments'].copy()

# %%
df_ori.head()
# Out:
#          user_name         user_location  \
# 0           ᏉᎥ☻լꂅϮ            astroworld
# 1    Tom Basile 🇺🇸          New York, NY
# 2  Time4fisticuffs      Pewee Valley, KY
# 3      ethel mertz  Stuck in the Middle
# 4         DIPR-J&K     Jammu and Kashmir
#
#                                     user_description         user_created  \
# 0  wednesday addams as a disney princess keepin i...  2017-05-26 05:46:42
# 1  Husband, Father, Columnist & Commentator. Auth...  2009-04-16 20:06:23
# 2  #Christian #Catholic #Conservative #Reagan #Re...  2009-02-28 18:57:41
# 3  #Browns #Indians #ClevelandProud #[]_[] #Cavs ...  2019-03-07 01:45:06
# 4  🖊️Official Twitter handle of Department of Inf...  2017-02-12 06:45:15
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0             624           950            18775          False
# 1            2253          1677               24           True
# 2            9275          9525             7254          False
# ...

# %%
df_ori.to_csv('covid19tweets.csv', index = False)
